# %%
from genie_eda import apply_eda 

import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("knn.csv")

# %%
df.head()
# Out:
#          X1        X2        X3         y
# 0 -0.059533  0.763686  0.317046 -0.070229
# 1  1.916473 -0.378508 -0.411538  1.887648
# 2 -0.237390 -0.244097 -1.053888 -0.316625
# 3 -0.579256  0.135478 -0.507913 -0.627537
# 4  0.873726 -1.569405  0.435819  0.987233

# %%
k = 3

# %%
df = apply_eda(df)
# Out:
# DataFrame shape:
# (719, 4)
#
#
# Checking for null values:
# Total Null values count: 0
# Checking for multicollinearity:
#           X1        X2        X3         y
# X1  1.000000 -0.120902 -0.021152  0.995367
# X2 -0.120902  1.000000  0.097814 -0.161638
# X3 -0.021152  0.097814  1.000000  0.061218
# y   0.995367 -0.161638  0.061218  1.000000
# Features and their VIF values:
#   Feature           VIF
# 0      X1           inf
# 1      X2  9.007199e+15
# 2      X3           inf
# 3       y           inf
# Features after removing features with VIF >= 10:
# Index(['X2', 'X3', 'y'], dtype='object')
# VIF of remaining features:
#   Feature       VIF
# 0      X2  1.039258
# 1      X3  1.015962
# 2       y  1.033179
# C:\Users\sahit\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:195: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)

# %%
df.head()
# Out:
#          X2        X3         y
# 0  0.763686  0.317046 -0.070229
# 1 -0.378508 -0.411538  1.887648
# 2 -0.244097 -1.053888 -0.316625
# 3  0.135478 -0.507913 -0.627537
# 4 -1.569405  0.435819  0.987233

# %%
X = df[['X2','X3']]
y = df.y
